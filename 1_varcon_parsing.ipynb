# %% [markdown]
# Let's read the file:

# %%
f = "varcon.txt"

with open(f, "r") as file:
    content = file.read()

# %% [markdown]
# Reminder: file looks like this:
#
# ```
# # abettor <verified> (level 50)
# A Bv C: abettor / Av B: abetter
# A Bv C: abettors / Av B: abetters
# A Bv C: abettor's / Av B: abetter's
#
# # adviser <verified> (level 20)
# A B C: adviser / A. Bv C.: advisor
# A B C: advisers / A. Bv C.: advisors
# A B C: adviser's / A. Bv C.: advisor's
# ## The oxford dictionary has this to say:
# ##     The spellings adviser and advisor are both correct. Adviser is more
# ##     common, but advisor is also widely used , especially in North
# ##     America. Adviser may be seen as less formal, while advisor often
# ##     suggests an official position.
#
# # airstrike (level 55)
# _: airstrike / _v: air_strike
# _: airstrikes / _v: air_strikes
# _: airstrike's / _v: air_strike's
#
# # apprize (level 60)
# A Z: apprize / B: apprise | value highly
# A Z: apprize's / B: apprise's | value highly
# A Z: apprizing / B: apprising | value highly
# A Z: apprized / B: apprised | value highly
# A Z: apprizes / B: apprises | value highly
# A B: apprise | inform
# A B: apprise's | inform
# A B: apprising | inform
# A B: apprised | inform
# A B: apprises | inform
#
# ```
#
# My idea:
# * Obviously comments like above will not be manually read and put in order.
# * I will look only at categories `A` for American variety and `B` or `Z` for Brittish variety.
# * For now I will not look at versions of spellings (e.g. `abettor` will be declared american, `abetter` will be declared brittish.)
# * It was noted that some words are underscore delimited instead of space delimited. This will be taken into account, <span style="color:red">but this means we would have to process word-N-grams, which we will not do in the first implementation.</span>
# * For now the `<verified>` flag and `(level NN)` information will not be propagated.
# * After inspecting the lexicon I assume the american version will be given first.
# * The lines with inconsistent formatting will be discarded. (See last example.)
#
# What to do when we have a case like this: `A Z: abnormalizing / B: abnormalising` ?
#
# It is clear that the `B` version is more informative in the sense that if we see `abnormalising`, the spelling is surely brittish, whereas the alternative could be american or could be "-ize" brittish. In this case I propose we only use the definitively brittish form.

# %%
items = content.split("# ")[1:]
items[3].split("\n")
# Out:
# ['abnormalizing (level 95)', 'A Z: abnormalizing / B: abnormalising', '', '']

# %%
from parse import compile
import logging
pattern = """{flags1}: {version1} / {flags2}: {version2}"""
p = compile(pattern)

def process_flags(flags:str) -> set:
    flags = flags.split(" ")
    flags = [flag for flag in flags if flag in ["A", "B", "Z"]]
    return set(flags)

def process_item(item:str) -> dict:
    pattern = """{flags1}: {version1} / {flags2}: {version2}"""
    p = compile(pattern)
    pattern2 = """{flags1}: {version1} / {flags2}: {version2} / {flags3}: {version3}"""
    p2 = compile(pattern2)
    resulting_dict = dict()
    lines = item.split("\n")
    for line in lines[1:]:
        if "|" in line:
            continue
        if line.startswith("#") or line == "":
            continue
        if line.count("/") == 1:
            try:
                results = p.parse(line)
                flags1 = process_flags(results["flags1"])
                flags2 = process_flags(results["flags2"])
                version1 = results["version1"].replace("_", " ").casefold()
                version2 = results["version2"].replace("_", " ").casefold()
                
                if (flags1, flags2) == ({"A"}, {"B"}):
                    resulting_dict[version1] = "A"
                    resulting_dict[version2] = "B"
                if (flags1, flags2) == ({"A", "Z"}, {"B"}):
                    resulting_dict[version2] = "B"
            except Exception as e:
                logging.debug(f"Found error {e} for line:")
                logging.debug(line)
        elif line.count("/") == 2:
            try:
                results = p2.parse(line)
                flags1 = process_flags(results["flags1"])
                flags2 = process_flags(results["flags2"])
                flags3 = process_flags(results["flags3"])
                version1 = results["version1"].replace("_", " ").casefold()
                version2 = results["version2"].replace("_", " ").casefold()
                version3 = results["version3"].replace("_", " ").casefold()

                if "A" in flags1:
                    american = version1
                if "A" in flags2:
                    american = version2
                if "A" in flags3:
                    american = version3
                if "B" in flags1:
                    brittish = version1
                if "B" in flags2:
                    brittish = version2
                if "B" in flags3:
                    brittish = version3
                
                if brittish != american:
                    resulting_dict[american] = "A"
                    resulting_dict[brittish] = "B"
            except Exception as e:
                logging.debug(f"Found error {e} for line:")
                logging.debug(line)
        else:
            logging.warning(f"Weird formatting with 0 or >2 slashes:\n{line}")
    return resulting_dict

def get_lexicon():
    f = "varcon.txt"
    with open(f, "r") as file:
        content = file.read()
    items = content.split("# ")[1:]
    results = {}
    for item in items:
        results.update(process_item(item))

    return results

get_lexicon()
# Out:
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B D 1: amoebas / Av Bv Dv 1: amoebae / Av Dv 2: amebas / Av Dv 2: amebae
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B 1 2: aunties
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: backward
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A Av B: battleaxes
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: boatswain / _v: bosun / _V: bo'sun / _V: bos'n / _V: bo's'n
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: boatswains / _v: bosuns / _V: bo's'ns / _V: bo'suns / _V: bos'ns
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: boatswain's / _v: bosun's / _V: bo'sun's / _V: bo's'n's / _V: bos'n's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: buss
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: busses
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: bussing
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: bussed
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _ _.: cabbies
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: camelhair
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: cesarean / _v: caesarean / _V 1: caesarian / _V 2: cesarian
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: cesareans / _v: caesareans / _V 1: caesarians / _V 2: cesarians
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: cesarean's / _v: caesarean's / _V 1: caesarian's / _V 2: cesarian's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A C: chilies / AV Cv: chiles / AV: chilis / AV B: chillies
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: chutzpah / _V 1: hutzpa / _V 2: chutzpa / _V 3: hutzpah
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: chutzpah's / _V 1: hutzpa's / _V 2: chutzpa's / _V 3: hutzpah's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: chutzpahes / _V 1: hutzpas / _V 2: chutzpas / _V 3: hutzpahes
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B 1 2: dissed
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B 1 2: dissing
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A AV B C Cv: distilled
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A AV B C Cv: distilling
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _ 1 2: dogies
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B C Cv: enthralling
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B C Cv: enthralled
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A C Dv: esophagi / Av Cv: esophaguses / B D: oesophagi / Bv: oesophaguses
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: faggot
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: faggots
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: faggot's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: garrote / _v: garotte / _v: garrotte / _V: garote
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: garroted / _v: garotted / _v: garrotted / _V: garoted
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: garroting / _v: garrotting / _v: garotting / _V: garoting
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: garrotes / _v: garottes / _v: garrottes / _V: garotes
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: garrote's / _v: garotte's / _v: garrotte's / _V: garote's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: ginkgoes / _v: ginkgos / _V: gingkos / _V: gingkoes
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A Av B Bv: goodies
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: griffon
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: griffons
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: griffon's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _ _V: hoagies
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: hovercraft
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A: impaneled / Av: empaneled / B Cv: impanelled / Bv C: empanelled
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A: impaneling / Av: empaneling / B Cv: impanelling / Bv C: empanelling
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _ 1: jinni / _v 2: jinn / _V 3: djinni / _V 4: djinn
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _ 1: jinni's / _v 2: jinn's / _V 3: djinni's / _V 4: djinn's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: kabbalah / _v: cabala / _v: kabbala / _V: kabala / _V: cabbala / _V: cabbalah
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: level
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: pilaf / _V 1: pilaw / _V 2: pilau / _V 3: pilaff
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: pilafs / _V 1: pilaws / _V 2: pilaus / _V 3: pilaffs
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: pilaf's / _V 1: pilaw's / _V 2: pilau's / _V 3: pilaff's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: preview
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: previews
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: preview's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: racket
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: racketed
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: racketing
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: rackets
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: racket's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _ _V: ropier
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _ _V: ropiest
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _ 1: schlep / _v 2: schlepp / _V 3: shlep / _V 4: shlepp
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _ 1: schleps / _v 2: schlepps / _V 3: shleps / _V 4: shlepps
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _ 1: schlep's / _v 2: schlepp's / _V 3: shlepp's / _V 4: shlep's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: schlock / _v: schlocky / _V 1: shlock / _V 2: shlocky
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B C: smidgen / AV Bv Cv 1: smidgeon / AV Cv 2: smidge / AV Bv Cv 3: smidgin
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B C: smidgens / AV Bv Cv 1: smidgeons / AV Cv 2: smidges / AV Bv Cv 3: smidgins
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B C: smidgen's / AV Bv Cv 1: smidgeon's / AV Cv 2: smidge's / AV Bv Cv 3: smidgin's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: soignee
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _: stageyness
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B B-: tassel
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: ton
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B: ton's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B Cv Dv: yogurt / Bv Cv D: yoghurt / Bv DV: yoghourt / C: yogourt
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B Cv Dv: yogurt's / Bv Cv D: yoghurt's / Bv DV: yoghourt's / C: yogourt's
# WARNING:root:Weird formatting with 0 or >2 slashes:
# A B Cv Dv: yogurts / Bv Cv D: yoghurts / Bv DV: yoghourts / C: yogourts
# WARNING:root:Weird formatting with 0 or >2 slashes:
# _ _V: adrenalines
# {'abettor': 'A',
#  'abetter': 'B',
#  'abettors': 'A',
#  'abetters': 'B',
#  "abettor's": 'A',
#  "abetter's": 'B',
#  'abnormalise': 'B',
#  'abnormalised': 'B',
#  'abnormalising': 'B',
#  'abolitionise': 'B',
#  'abolitionised': 'B',
#  'abolitionising': 'B',
#  'abridgment': 'A',
#  'abridgement': 'B',
#  'abridgments': 'A',
#  'abridgements': 'B',
#  "abridgment's": 'A',
#  "abridgement's": 'B',
#  'academise': 'B',
#  'academised': 'B',
#  'academising': 'B',
#  'acalephe': 'A',
#  'acalephae': 'B',
#  'accessorise': 'B',
#  'accessorised': 'B',
#  'accessorising': 'B',
#  'accessorises': 'B',
#  'acclimatisable': 'B',
#  'acclimatisation': 'B',
#  "acclimatisation's": 'B',
#  'acclimatise': 'B',
#  'acclimatised': 'B',
#  'acclimatising': 'B',
#  'acclimatises': 'B',
#  'acclimatiser': 'B',
#  'acclimatisers': 'B',
#  'accorage': 'A',
#  'accourage': 'B',
#  'accoraged': 'A',
#  'accouraged': 'B',
#  'accoraging': 'A',
#  'accouraging': 'B',
#  'accorages': 'A',
#  'accourages': 'B',
#  'accouter': 'A',
#  'accoutre': 'B',
#  'accoutered': 'A',
#  'accoutred': 'B',
#  'accoutering': 'A',
#  'accoutring': 'B',
#  'accouters': 'A',
#  'accoutres': 'B',
#  'accouterment': 'A',
#  'accoutrement': 'B',
#  'accouterments': 'A',
#  'accoutrements': 'B',
#  "accouterment's": 'A',
#  "accoutrement's": 'B',
#  'acemetae': 'A',
#  'acoemetae': 'B',
#  "acemetae's": 'A',
#  "acoemetae's": 'B',
#  'acemetic': 'A',
#  'acoemetic': 'B',
#  "acemetic's": 'A',
#  "acoemetic's": 'B',
#  'acer': 'A',
#  'acre': 'B',
#  "acer's": 'A',
#  "acre's": 'B',
#  'acetonemia': 'A',
#  'acetonaemia': 'B',
#  'acetonemic': 'A',
#  'acetonaemic': 'B',
#  'achenia': 'A',
#  'achaenia': 'B',
#  'achenium': 'A',
#  'achaenium': 'B',
#  'acheniums': 'A',
#  'achaeniums': 'B',
#  'achenocarp': 'A',
#  'achaenocarp': 'B',
#  'achroiocythemia': 'A',
#  'achroiocythaemia': 'B',
#  'achromatisation': 'B',
#  'achromatisations': 'B',
#  "achromatisation's": 'B',
#  'achromatise': 'B',
#  'achromatised': 'B',
#  'achromatising': 'B',
#  'achromatises': 'B',
#  'acidemia': 'A',
#  'acidaemia': 'B',
#  'acknowledgment': 'A',
#  'acknowledgement': 'B',
#  'acknowledgments': 'A',
#  'acknowledgements': 'B',
#  "acknowledgment's": 'A',
#  "acknowledgement's": 'B',
#  'acmesthesia': 'A',
#  'acmaesthesia': 'B',
#  'acroanesthesia': 'A',
#  'acroanaesthesia': 'B',
#  'acroesthesia': 'A',
#  'acroaesthesia': 'B',
#  'actualisation': 'B',
#  'actualisations': 'B',
#  "actualisation's": 'B',
#  'actualise': 'B',
#  'actualised': 'B',
#  'actualising': 'B',
#  'actualises': 'B',
#  'acuesthesia': 'A',
#  'acuaesthesia': 'B',
#  'adapter': 'A',
#  'adaptor': 'B',
#  'adapters': 'A',
#  'adaptors': 'B',
#  "adapter's": 'A',
#  "adaptor's": 'B',
#  'adonise': 'B',
#  'adonised': 'B',
#  'adonising': 'B',
#  'adonises': 'B',
#  'adulterise': 'B',
#  'adulterised': 'B',
#  'adulterising': 'B',
#  'adulterises': 'B',
#  'advene': 'A',
#  'advenae': 'B',
#  'adverbialise': 'B',
#  'adverbialised': 'B',
#  'adverbialising': 'B',
#  'adverbialises': 'B',
#  'advertisable': 'B',
#  'aedon': 'A',
#  'aaedon': 'B',
#  "aedon's": 'A',
#  "aaedon's": 'B',
#  'aeetes': 'A',
#  'aeaetes': 'B',
#  "aeetes's": 'A',
#  "aeaetes's": 'B',
#  'aerialness': 'A',
#  'aaerialness': 'B',
#  "aerialness's": 'A',
#  "aaerialness's": 'B',
#  'aeric': 'B',
#  'areic': 'B',
#  'eric': 'A',
#  'aerographer': 'A',
#  'areographer': 'B',
#  'aerographic': 'A',
#  'areographic': 'B',
#  'aerographical': 'A',
#  'areographical': 'B',
#  'aerography': 'A',
#  'areography': 'B',
#  'aerographies': 'A',
#  'areographies': 'B',
#  "aerography's": 'A',
#  "areography's": 'B',
#  'aerologic': 'A',
#  'areologic': 'B',
#  'aerological': 'A',
#  'areological': 'B',
#  'aerologist': 'A',
#  'areologist': 'B',
#  "aerologist's": 'A',
#  "areologist's": 'B',
#  'aerology': 'A',
#  'areology': 'B',
#  'aerologies': 'A',
#  'areologies': 'B',
#  "aerology's": 'A',
#  "areology's": 'B',
#  'aerometer': 'A',
#  'areometer': 'B',
#  'aerometers': 'A',
#  'areometers': 'B',
#  'aerometric': 'A',
#  'areometric': 'A',
#  'araeometric': 'B',
#  'aerope': 'A',
#  'aaerope': 'B',
#  "aerope's": 'A',
#  "aaerope's": 'B',
#  'aestheticise': 'B',
#  'aestheticised': 'B',
#  'aestheticising': 'B',
#  'aestheticises': 'B',
#  'affeer': 'A',
#  'affere': 'B',
#  'africanisation': 'B',
#  'africanisations': 'B',
#  "africanisation's": 'B',
#  'africanise': 'B',
#  'africanised': 'B',
#  'africanising': 'B',
#  'africanises': 'B',
#  'afrikanerisation': 'B',
#  'afrikanerise': 'B',
#  'afrikanerised': 'B',
#  'afrikanerising': 'B',
#  'afrikanerises': 'B',
#  'agathodemon': 'A',
#  'agathodaemon': 'B',
#  'agatise': 'B',
#  'agatises': 'B',
#  'agenise': 'B',
#  'ager': 'A',
#  'agre': 'B',
#  'aggrandisable': 'B',
#  'aggrandisables': 'B',
#  "aggrandisable's": 'B',
#  'aggrandisation': 'B',
#  'aggrandise': 'B',
#  'aggrandised': 'B',
#  'aggrandising': 'B',
#  'aggrandises': 'B',
#  'aggrandisement': 'B',
#  'aggrandisements': 'B',
#  "aggrandisement's": 'B',
#  'aggrandiser': 'B',
#  'aggrandisers': 'B',
#  "aggrandiser's": 'B',
#  'aging': 'A',
#  'ageing': 'B',
#  'agings': 'A',
#  'ageings': 'B',
#  "aging's": 'A',
#  "ageing's": 'B',
#  'agnise': 'B',
#  'agnised': 'B',
#  'agnising': 'B',
#  'agnises': 'B',
#  'agonise': 'B',
#  'agonised': 'B',
#  'agonising': 'B',
#  'agonises': 'B',
#  'agonisedly': 'B',
#  'agonisedlies': 'B',
#  'agoniser': 'B',
#  'agonisers': 'B',
#  'agonisingly': 'B',
#  'agonisinglier': 'B',
#  'agonisingliest': 'B',
#  'agrarianise': 'B',
#  'agrarianises': 'B',
#  'agrise': 'B',
#  'agrised': 'B',
#  'agrising': 'B',
#  'agrises': 'B',
#  'aguise': 'B',
#  'aguised': 'B',
#  'aguising': 'B',
#  'aguises': 'B',
#  'aiger': 'A',
#  'aigre': 'B',
#  'airfoil': 'A',
#  'aerofoil': 'B',
#  'airfoils': 'A',
#  'aerofoils': 'B',
#  "airfoil's": 'A',
#  "aerofoil's": 'B',
#  'airgel': 'A',
#  'aerogel': 'B',
#  'airplane': 'A',
#  'aeroplane': 'B',
#  'airplanes': 'A',
#  'aeroplanes': 'B',
#  "airplane's": 'A',
#  "aeroplane's": 'B',
#  'aker': 'A',
#  'akre': 'B',
#  'aktistete': 'A',
#  'aktistetae': 'B',
#  "aktistete's": 'A',
#  "aktistetae's": 'B',
#  'albitise': 'B',
#  'albitised': 'B',
#  'albitising': 'B',
#  'albitises': 'B',
#  'albumenization': 'A',
#  'albuminisation': 'B',
#  'albumenizations': 'A',
#  'albuminisations': 'B',
#  "albumenization's": 'A',
#  "albuminisation's": 'B',
#  'albumenize': 'A',
#  'albuminise': 'B',
#  'albumenized': 'A',
#  'albuminised': 'B',
#  'albumenizing': 'A',
#  'albuminising': 'B',
#  'albumenizes': 'A',
#  'albuminises': 'B',
#  'albumeniser': 'B',
#  'alchemise': 'B',
#  'alchemised': 'B',
#  'alchemising': 'B',
#  'alchemises': 'B',
#  'alcide': 'A',
#  'alcidae': 'B',
#  "alcide's": 'A',
#  "alcidae's": 'B',
#  'alcithoe': 'A',
#  'alcithoae': 'B',
#  "alcithoe's": 'A',
#  "alcithoae's": 'B',
#  'alcoholisable': 'B',
#  'alcoholisables': 'B',
#  "alcoholisable's": 'B',
#  'alcoholisation': 'B',
#  'alcoholisations': 'B',
#  "alcoholisation's": 'B',
#  'alcoholise': 'B',
#  'alcoholised': 'B',
#  'alcoholising': 'B',
#  'alcoholises': 'B',
#  'aleucemic': 'A',
#  'aleucaemic': 'B',
#  'aleukemic': 'A',
#  'aleukaemic': 'B',
#  'aleus': 'A',
#  'aloeus': 'B',
#  "aleus's": 'A',
#  "aloeus's": 'B',
#  'algebraisation': 'B',
#  'algebraisations': 'B',
#  "algebraisation's": 'B',
#  'algebraise': 'B',
#  'algebraises': 'B',
#  'algesthesis': 'A',
#  'algaesthesis': 'B',
#  'alienise': 'B',
#  'alienises': 'B',
#  'alkalinisation': 'B',
#  'alkalinisations': 'B',
#  "alkalinisation's": 'B',
#  'alkalinise': 'B',
#  'alkalinised': 'B',
#  'alkalinising': 'B',
#  'alkalinises': 'B',
#  'alkalisable': 'B',
#  'alkalisation': 'B',
#  'alkalisations': 'B',
#  "alkalisation's": 'B',
#  'alkalise': 'B',
#  'alkalised': 'B',
#  'alkalising': 'B',
#  'alkalises': 'B',
#  'alkaliser': 'B',
#  "alkaliser's": 'B',
#  'allegorisation': 'B',
#  'allegorisations': 'B',
#  "allegorisation's": 'B',
#  'allegorise': 'B',
#  'allegorised': 'B',
#  'allegorising': 'B',
#  'allegorises': 'B',
#  'allegoriser': 'B',
#  'allegorisers': 'B',
#  "allegoriser's": 'B',
#  'alloxuremia': 'A',
#  'alloxuraemia': 'B',
#  'alphabetisation': 'B',
#  'alphabetisations': 'B',
#  "alphabetisation's": 'B',
#  'alphabetise': 'B',
#  'alphabetised': 'B',
#  'alphabetising': 'B',
#  'alphabetises': 'B',
#  'alphabetiser': 'B',
#  'alphabetisers': 'B',
#  "alphabetiser's": 'B',
#  'alternise': 'B',
#  'alternises': 'B',
#  'althea': 'A',
#  'althaea': 'B',
#  'altheas': 'A',
#  'althaeas': 'B',
#  "althea's": 'A',
#  "althaea's": 'B',
#  'althein': 'A',
#  'althaein': 'B',
#  'aluminisation': 'B',
#  'aluminise': 'B',
#  'aluminised': 'B',
#  'aluminising': 'B',
#  'aluminises': 'B',
#  'aluminum': 'A',
#  'aluminium': 'B',
#  'aluminums': 'A',
#  'aluminiums': 'B',
#  "aluminum's": 'A',
#  "aluminium's": 'B',
#  'alveole': 'A',
#  'alveolae': 'B',
#  'amalgamatise': 'B',
#  'amalgamatises': 'B',
#  'amalgamisation': 'B',
#  'amalgamisations': 'B',
#  "amalgamisation's": 'B',
#  'amalgamise': 'B',
#  'amalgamises': 'B',
#  'amalthea': 'A',
#  'amalthaea': 'B',
#  "amalthea's": 'A',
#  "amalthaea's": 'B',
#  'ambiance': 'A',
#  'ambience': 'B',
#  'ambiances': 'A',
#  'ambiences': 'B',
#  "ambiance's": 'A',
#  "ambience's": 'B',
#  'ambicolorate': 'A',
#  'ambicolourate': 'B',
#  'ambicoloration': 'A',
#  'ambicolouration': 'B',
#  'ambilevous': 'A',
#  'ambilaevous': 'B',
#  'ameban': 'A',
#  'amoeban': 'B',
#  'amebean': 'A',
#  'amoebean': 'B',
#  'amebian': 'A',
#  'amoebian': 'B',
#  'amebiasis': 'A',
#  'amoebiasis': 'B',
#  'amebiases': 'A',
#  'amoebiases': 'B',
#  'amebicidal': 'A',
#  'amoebicidal': 'B',
#  'amebicide': 'A',
#  'amoebicide': 'B',
#  'amebid': 'A',
#  'amoebid': 'B',
#  'amebiform': 'A',
#  'amoebiform': 'B',
#  'amebiosis': 'A',
#  'amoebiosis': 'B',
#  'amebocyte': 'A',
#  'amoebocyte': 'B',
#  'amebocytes': 'A',
#  'amoebocytes': 'B',
#  "amebocyte's": 'A',
#  "amoebocyte's": 'B',
#  'ameboidism': 'A',
#  'amoeboidism': 'B',
#  "ameboidism's": 'A',
#  "amoeboidism's": 'B',
#  'amebous': 'A',
#  'amoebous': 'B',
#  'amebula': 'A',
#  'amoebula': 'B',
#  'amenorrhea': 'A',
#  'amenorrhoea': 'B',
#  'amenorrheas': 'A',
#  'amenorrhoeas': 'B',
#  "amenorrhea's": 'A',
#  "amenorrhoea's": 'B',
#  'amenorrheal': 'A',
#  'amenorrhoeal': 'B',
#  'amenorrheic': 'A',
#  'amenorrhoeic': 'B',
#  'americanisation': 'B',
#  'americanisations': 'B',
#  "americanisation's": 'B',
#  'americanise': 'B',
#  'americanised': 'B',
#  'americanising': 'B',
#  'americanises': 'B',
#  'americaniser': 'B',
#  'americanisers': 'B',
#  "americaniser's": 'B',
#  'ammocete': 'A',
#  'ammocoete': 'B',
#  'ammocetes': 'A',
#  'ammocoetes': 'B',
#  "ammocete's": 'A',
#  "ammocoete's": 'B',
#  'ammoniemia': 'A',
#  'ammoniaemia': 'B',
#  'amongst': 'B',
#  'amoralise': 'B',
#  'amoralises': 'B',
#  'amoret': 'A',
#  'amouret': 'B',
#  'amorism': 'A',
#  'amourism': 'B',
#  'amorisms': 'A',
#  'amourisms': 'B',
#  "amorism's": 'A',
#  "amourism's": 'B',
#  'amorist': 'A',
#  'amourist': 'B',
#  'amorists': 'A',
#  'amourists': 'B',
#  "amorist's": 'A',
#  "amourist's": 'B',
#  'amoristic': 'A',
#  'amouristic': 'B',
#  'amoristics': 'A',
#  'amouristics': 'B',
#  'amorphisation': 'B',
#  'amorphise': 'B',
#  'amortisable': 'B',
#  'amortisabler': 'B',
#  'amortisables': 'B',
#  'amortisablest': 'B',
#  "amortisable's": 'B',
#  'amortisation': 'B',
#  'amortisations': 'B',
#  "amortisation's": 'B',
#  'amortise': 'B',
#  'amortised': 'B',
#  'amortising': 'B',
#  'amortises': 'B',
#  'amortisement': 'B',
#  'amortisements': 'B',
#  "amortisement's": 'B',
#  'amphigean': 'A',
#  'amphigaean': 'B',
#  'amphitheater': 'A',
#  'amphitheatre': 'B',
#  'amphitheaters': 'A',
#  'amphitheatres': 'B',
#  "amphitheater's": 'A',
#  "amphitheatre's": 'B',
#  'amygdale': 'A',
#  'amygdalae': 'B',
#  'amyxorrhea': 'A',
#  'amyxorrhoea': 'B',
#  'anabaptise': 'B',
#  'anabaptised': 'B',
#  'anabaptising': 'B',
#  'anabaptises': 'B',
#  'anagrammatise': 'B',
#  'anagrammatised': 'B',
#  'anagrammatising': 'B',
#  'anagrammatises': 'B',
#  'analogise': 'B',
#  'analogised': 'B',
#  'analogising': 'B',
#  'analogises': 'B',
#  'analyzability': 'A',
#  'analysability': 'B',
#  "analyzability's": 'A',
#  "analysability's": 'B',
#  'analyzable': 'A',
#  'analysable': 'B',
#  'analyzabler': 'A',
#  'analysabler': 'B',
#  'analyzablest': 'A',
#  'analysablest': 'B',
#  'analyzation': 'A',
#  'analysation': 'B',
#  'analyzations': 'A',
#  'analysations': 'B',
#  "analyzation's": 'A',
#  "analysation's": 'B',
#  'analyze': 'A',
#  'analyse': 'B',
#  'analyzed': 'A',
#  'analysed': 'B',
#  'analyzing': 'A',
#  'analysing': 'B',
#  'analyzes': 'A',
#  'analyses': 'B',
#  'analyzer': 'A',
#  'analyser': 'B',
#  'analyzers': 'A',
#  'analysers': 'B',
#  "analyzer's": 'A',
#  "analyser's": 'B',
#  'anapestically': 'A',
#  'anapaestically': 'B',
#  'anapneic': 'A',
#  'anapnoeic': 'B',
#  'anarchise': 'B',
#  'anarchised': 'B',
#  'anarchising': 'B',
#  'anarchises': 'B',
#  'anathematisation': 'B',
#  'anathematisations': 'B',
#  "anathematisation's": 'B',
#  'anathematise': 'B',
#  'anathematised': 'B',
#  'anathematising': 'B',
#  'anathematises': 'B',
#  'anathematiser': 'B',
#  "anathematiser's": 'B',
#  'anatomisable': 'B',
#  'anatomisation': 'B',
#  "anatomisation's": 'B',
#  'anatomise': 'B',
#  'anatomised': 'B',
#  'anatomising': 'B',
#  'anatomises': 'B',
#  'anatomiser': 'B',
#  "anatomiser's": 'B',
#  'anchinoe': 'A',
#  'anchinoae': 'B',
#  "anchinoe's": 'A',
#  "anchinoae's": 'B',
#  'ancille': 'A',
#  'ancillae': 'B',
#  'anematosis': 'A',
#  'anaematosis': 'B',
#  'anemia': 'A',
#  'anaemia': 'B',
#  'anemias': 'A',
#  'anaemias': 'B',
#  "anemia's": 'A',
#  "anaemia's": 'B',
#  'anemic': 'A',
#  'anaemic': 'B',
#  'anemicer': 'A',
#  'anaemicer': 'B',
#  'anemicest': 'A',
#  'anaemicest': 'B',
#  'anemics': 'A',
#  'anaemics': 'B',
#  'anemically': 'A',
#  'anaemically': 'B',
#  'aneretic': 'A',
#  'anaeretic': 'B',
#  'anesis': 'A',
#  'anoesis': 'B',
#  'anesthesia': 'A',
#  'anaesthesia': 'B',
#  'anesthesias': 'A',
#  'anaesthesias': 'B',
#  "anesthesia's": 'A',
#  "anaesthesia's": 'B',
#  'anesthesiant': 'A',
#  'anaesthesiant': 'B',
#  'anesthesiologist': 'A',
#  'anaesthesiologist': 'B',
#  'anesthesiologists': 'A',
#  'anaesthesiologists': 'B',
#  "anesthesiologist's": 'A',
#  "anaesthesiologist's": 'B',
#  'anesthesiology': 'A',
#  'anaesthesiology': 'B',
#  'anesthesiologies': 'A',
#  'anaesthesiologies': 'B',
#  "anesthesiology's": 'A',
#  "anaesthesiology's": 'B',
#  'anesthesis': 'A',
#  'anaesthesis': 'B',
#  'anesthetic': 'A',
#  'anaesthetic': 'B',
#  'anestheticer': 'A',
#  'anaestheticer': 'B',
#  'anestheticest': 'A',
#  'anaestheticest': 'B',
#  'anesthetics': 'A',
#  'anaesthetics': 'B',
#  "anesthetic's": 'A',
#  "anaesthetic's": 'B',
#  'anesthetically': 'A',
#  'anaesthetically': 'B',
#  'anesthetist': 'A',
#  'anaesthetist': 'B',
#  'anesthetists': 'A',
#  'anaesthetists': 'B',
#  "anesthetist's": 'A',
#  "anaesthetist's": 'B',
#  'anesthetization': 'A',
#  'anaesthetisation': 'B',
#  'anesthetizations': 'A',
#  'anaesthetisations': 'B',
#  "anesthetization's": 'A',
#  "anaesthetisation's": 'B',
#  'anesthetize': 'A',
#  'anaesthetise': 'B',
#  'anesthetized': 'A',
#  'anaesthetised': 'B',
#  'anesthetizing': 'A',
#  'anaesthetising': 'B',
#  'anesthetizes': 'A',
#  'anaesthetises': 'B',
#  'anesthetizer': 'A',
#  'anaesthetiser': 'B',
#  'anesthetizers': 'A',
#  'anaesthetisers': 'B',
#  'anesthyl': 'A',
#  'anaesthyl': 'B',
#  'anestri': 'A',
#  'anoestri': 'B',
#  'anestrous': 'A',
#  'anoestrous': 'B',
#  'anestrum': 'A',
#  'anoestrum': 'B',
#  'anestra': 'A',
#  'anoestra': 'B',
#  'anestrus': 'A',
#  'anoestrus': 'B',
#  'anestruses': 'A',
#  'anoestruses': 'B',
#  "anestrus's": 'A',
#  "anoestrus's": 'B',
#  'anetic': 'A',
#  'anoetic': 'B',
#  'anetiological': 'A',
#  'anaetiological': 'B',
#  'angelicise': 'B',
#  'angelicises': 'B',
#  'angelise': 'B',
#  'angelises': 'B',
#  'anglicanise': 'B',
#  'anglicanises': 'B',
#  "anglicanise's": 'B',
#  'anglicisation': 'B',
#  'anglicisations': 'B',
#  "anglicisation's": 'B',
#  'anglicise': 'B',
#  'anglicised': 'B',
#  'anglicising': 'B',
#  'anglicises': 'B',
#  'angrecum': 'A',
#  'angraecum': 'B',
#  'angularisation': 'B',
#  'angularisations': 'B',
#  "angularisation's": 'B',
#  'angularise': 'B',
#  'angularises': 'B',
#  'anhematopoiesis': 'A',
#  'anhaematopoiesis': 'B',
#  "anhematopoiesis's": 'A',
#  "anhaematopoiesis's": 'B',
#  'anhematosis': 'A',
#  'anhaematosis': 'B',
#  'anhemolytic': 'A',
#  'anhaemolytic': 'B',
#  'anhydremia': 'A',
#  'anhydraemia': 'B',
#  'anhydremic': 'A',
#  'anhydraemic': 'B',
#  'anhydridisation': 'B',
#  'anhydridisations': 'B',
#  "anhydridisation's": 'B',
#  'anhydridise': 'B',
#  'anhydridises': 'B',
#  'animalisation': 'B',
#  'animalisations': 'B',
#  "animalisation's": 'B',
#  'animalise': 'B',
#  'animalised': 'B',
#  'animalising': 'B',
#  'animalises': 'B',
#  'animised': 'B',
#  'annalise': 'B',
#  'annalised': 'B',
#  'annalising': 'B',
#  'annalises': 'B',
#  'annualisation': 'B',
#  'annualise': 'B',
#  'annualised': 'B',
#  'annualising': 'B',
#  'annualises': 'B',
#  'anodisation': 'B',
#  'anodise': 'B',
#  'anodised': 'B',
#  'anodising': 'B',
#  'anodises': 'B',
#  'anonymise': 'B',
#  'anonymised': 'B',
#  'anonymising': 'B',
#  'anonymises': 'B',
#  'anora': 'A',
#  'anoura': 'B',
#  "anora's": 'A',
#  "anoura's": 'B',
#  'anoxemia': 'A',
#  'anoxaemia': 'B',
#  "anoxemia's": 'A',
#  "anoxaemia's": 'B',
#  'anoxemic': 'A',
#  'anoxaemic': 'B',
#  'anserine': 'A',
#  'anserinae': 'B',
#  'antagonisable': 'B',
#  'antagonisation': 'B',
#  'antagonisations': 'B',
#  "antagonisation's": 'B',
#  'antagonise': 'B',
#  'antagonised': 'B',
#  'antagonising': 'B',
#  'antagonises': 'B',
#  'antagoniser': 'B',
#  'antagonisers': 'B',
#  'anthecological': 'A',
#  'anthoecological': 'B',
#  'anthecologist': 'A',
#  'anthoecologist': 'B',
#  'anthecology': 'A',
#  'anthoecology': 'B',
#  'anthologisation': 'B',
#  'anthologise': 'B',
#  'anthologised': 'B',
#  'anthologising': 'B',
#  'anthologises': 'B',
#  'anthologiser': 'B',
#  'anthracemia': 'A',
#  'anthracaemia': 'B',
#  'anthracitisation': 'B',
#  'anthracitisations': 'B',
#  "anthracitisation's": 'B',
#  'anthropomorphisation': 'B',
#  'anthropomorphisations': 'B',
#  "anthropomorphisation's": 'B',
#  'anthropomorphise': 'B',
#  'anthropomorphised': 'B',
#  'anthropomorphising': 'B',
#  'anthropomorphises': 'B',
#  'anticatalyzer': 'A',
#  'anticatalyser': 'B',
#  'anticatalyzers': 'A',
#  'anticatalysers': 'B',
#  "anticatalyzer's": 'A',
#  "anticatalyser's": 'B',
#  'anticentralisation': 'B',
#  'anticentralisations': 'B',
#  "anticentralisation's": 'B',
#  'anticise': 'B',
#  'anticises': 'B',
#  'antiepicenter': 'A',
#  'antiepicentre': 'B',
#  'antiepicenters': 'A',
#  'antiepicentres': 'B',
#  "antiepicenter's": 'A',
#  "antiepicentre's": 'B',
#  'antifertiliser': 'B',
#  'antifertilisers': 'B',
#  "antifertiliser's": 'B',
#  'antilabor': 'A',
#  'antilabour': 'B',
#  'antilabors': 'A',
#  'antilabours': 'B',
#  "antilabor's": 'A',
#  "antilabour's": 'B',
#  'antilemic': 'A',
#  'antiloemic': 'B',
#  'antimedieval': 'A',
#  'antimediaeval': 'B',
#  'antimedievalism': 'A',
#  'antimediaevalism': 'B',
#  "antimedievalism's": 'A',
#  "antimediaevalism's": 'B',
#  'antimedievalist': 'A',
#  'antimediaevalist': 'B',
#  "antimedievalist's": 'A',
#  "antimediaevalist's": 'B',
#  'antimedievally': 'A',
#  'antimediaevally': 'B',
#  'antioxidiser': 'B',
#  'antioxidisers': 'B',
#  "antioxidiser's": 'B',
#  'antioxidising': 'B',
#  'antioxidisings': 'B',
#  "antioxidising's": 'B',
#  'antipathise': 'B',
#  'antipathises': 'B',
#  'antiquarianise': 'B',
#  'antiquarianises': 'B',
#  'antirumor': 'A',
#  'antirumour': 'B',
#  'antirumors': 'A',
#  'antirumours': 'B',
#  "antirumor's": 'A',
#  "antirumour's": 'B',
#  'antisensitise': 'B',
#  'antisensitises': 'B',
#  'antisensitiser': 'B',
#  'antisensitisers': 'B',
#  "antisensitiser's": 'B',
#  'antisepticise': 'B',
#  'antisepticised': 'B',
#  'antisepticising': 'B',
#  'antisepticises': 'B',
#  'antiseptise': 'B',
#  'antiseptises': 'B',
#  'antisiphon': 'A',
#  'antisyphon': 'B',
#  'antisiphons': 'A',
#  'antisyphons': 'B',
#  "antisiphon's": 'A',
#  "antisyphon's": 'B',
#  'antithesise': 'B',
#  'antithesises': 'B',
#  'anviled': 'A',
#  'anvilled': 'B',
#  'anviling': 'A',
#  'anvilling': 'B',
#  'apesthesia': 'A',
#  'apaesthesia': 'B',
#  'apesthetic': 'A',
#  'apaesthetic': 'B',
#  'apheresis': 'A',
#  'aphaeresis': 'B',
#  'aphereses': 'A',
#  'aphaereses': 'B',
#  "apheresis's": 'A',
#  "aphaeresis's": 'B',
#  'apheretic': 'A',
#  'aphaeretic': 'B',
#  'aphetise': 'B',
#  'aphetised': 'B',
#  'aphetising': 'B',
#  'aphetises': 'B',
#  'aphorise': 'B',
#  'aphorised': 'B',
#  'aphorising': 'B',
#  'aphorises': 'B',
#  'aphoriser': 'B',
#  'aphorisers': 'B',
#  "aphoriser's": 'B',
#  'apnea': 'A',
#  'apnoea': 'B',
#  'apneas': 'A',
#  'apnoeas': 'B',
#  "apnea's": 'A',
#  "apnoea's": 'B',
#  'apneal': 'A',
#  'apnoeal': 'B',
#  'apneic': 'A',
#  'apnoeic': 'B',
#  'apocenter': 'A',
#  'apocentre': 'B',
#  'apogeic': 'A',
#  'apogaeic': 'B',
#  'apologise': 'B',
#  'apologised': 'B',
#  'apologising': 'B',
#  'apologises': 'B',
#  'apologiser': 'B',
#  'apologisers': 'B',
#  "apologiser's": 'B',
#  'apophthegmatise': 'B',
#  'apophthegmatised': 'B',
#  'apophthegmatising': 'B',
#  'apophthegmatises': 'B',
#  'aporrhea': 'A',
#  'aporrhoea': 'B',
#  'apostatisation': 'B',
#  'apostatise': 'B',
#  'apostatised': 'B',
#  'apostatising': 'B',
#  'apostatises': 'B',
#  'apostolise': 'B',
#  'apostolised': 'B',
#  'apostolising': 'B',
#  'apostolises': 'B',
#  'apostrophise': 'B',
#  'apostrophised': 'B',
#  'apostrophising': 'B',
#  'apostrophises': 'B',
#  'apothegmatise': 'B',
#  'apothegmatised': 'B',
#  'apothegmatising': 'B',
#  'apothegmatises': 'B',
#  'apotheosise': 'B',
#  'apotheosised': 'B',
#  'apotheosising': 'B',
#  'apotheosises': 'B',
#  'appall': 'A',
#  'appal': 'B',
#  'appalls': 'A',
#  'appals': 'B',
#  'appareled': 'A',
#  'apparelled': 'B',
#  'appareling': 'A',
#  'apparelling': 'B',
#  'appetise': 'B',
#  'appetised': 'B',
#  'appetising': 'B',
#  'appetises': 'B',
#  'appetisement': 'B',
#  'appetisements': 'B',
#  "appetisement's": 'B',
#  'appetiser': 'B',
#  'appetisers': 'B',
#  "appetiser's": 'B',
#  'appetisingly': 'B',
#  'apprisal': 'B',
#  'appriser': 'B',
#  'apprisers': 'B',
#  'apprisings': 'B',
#  'arabianise': 'B',
#  'arabianises': 'B',
#  "arabianise's": 'B',
#  'arabicise': 'B',
#  'arabicises': 'B',
#  'arabisation': 'B',
#  'arabisations': 'B',
#  "arabisation's": 'B',
#  'arabise': 'B',
#  ...}

# %%
"///".count("/")
# Out:
# 3
